# %%
import pandas as pd
import json

import numpy as np
import matplotlib.pyplot as plt

fileName = 'usedDependenciesWithoutZeroDeps.csv'

usage = pd.read_csv(fileName)

Y = usage['percentage']

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 14})

plt.figure(figsize=(9,6), dpi=120)
n, bins, patches = plt.hist(Y, bins='doane')
plt.grid(axis='y', alpha=0.75)
plt.gca().set_xticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_xticks()]) 
plt.xlabel('Percentage of declared dependencies used')
plt.ylabel('Packages')
print(n,bins)
plt.savefig('{}.png'.format(fileName))
# Out:
# [  76493.     611.     906.    1915.    1731.    2471.     868.    3981.
#     1858.    8657.    1821.    3592.    2969.     665.   28434.    3365.
#     5569.    2677.   20529.    4398.    1222.   16080.   11045.    6991.
#     9786.    3774.    1831.  216675.] [ 0.          0.03571429  0.07142857  0.10714286  0.14285714  0.17857143
#   0.21428571  0.25        0.28571429  0.32142857  0.35714286  0.39285714
#   0.42857143  0.46428571  0.5         0.53571429  0.57142857  0.60714286
#   0.64285714  0.67857143  0.71428571  0.75        0.78571429  0.82142857
#   0.85714286  0.89285714  0.92857143  0.96428571  1.        ]
